# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 208.1697 - y1_output_loss: 99.3397 - y2_output_loss: 106.8657 - y1_output_root_mean_squared_error: 10.0150 - y2_output_root_mean_squared_error: 10.3861 - val_loss: 41.1162 - val_y1_output_loss: 16.1851 - val_y2_output_loss: 23.6332 - val_y1_output_root_mean_squared_error: 4.0871 - val_y2_output_root_mean_squared_error: 4.9408
# Epoch 2/500
# 614/614 [==============================] - 0s 169us/sample - loss: 32.8912 - y1_output_loss: 12.5027 - y2_output_loss: 20.1309 - y1_output_root_mean_squared_error: 3.5495 - y2_output_root_mean_squared_error: 4.5047 - val_loss: 31.1232 - val_y1_output_loss: 11.1473 - val_y2_output_loss: 18.9845 - val_y1_output_root_mean_squared_error: 3.3947 - val_y2_output_root_mean_squared_error: 4.4271
# Epoch 3/500
# 614/614 [==============================] - 0s 161us/sample - loss: 30.6552 - y1_output_loss: 11.3671 - y2_output_loss: 19.0833 - y1_output_root_mean_squared_error: 3.3754 - y2_output_root_mean_squared_error: 4.3889 - val_loss: 33.5168 - val_y1_output_loss: 13.0876 - val_y2_output_loss: 19.7128 - val_y1_output_root_mean_squared_error: 3.6594 - val_y2_output_root_mean_squared_error: 4.4862
# Epoch 4/500
# 614/614 [==============================] - 0s 165us/sample - loss: 21.8183 - y1_output_loss: 9.1889 - y2_output_loss: 13.0372 - y1_output_root_mean_squared_error: 3.0006 - y2_output_root_mean_squared_error: 3.5797 - val_loss: 84.6491 - val_y1_output_loss: 19.0517 - val_y2_output_loss: 64.0584 - val_y1_output_root_mean_squared_error: 4.4045 - val_y2_output_root_mean_squared_error: 8.0777
# Epoch 5/500
# 614/614 [==============================] - 0s 159us/sample - loss: 29.5874 - y1_output_loss: 10.5231 - y2_output_loss: 18.8541 - y1_output_root_mean_squared_error: 3.2533 - y2_output_root_mean_squared_error: 4.3593 - val_loss: 26.7878 - val_y1_output_loss: 10.0718 - val_y2_output_loss: 15.9463 - val_y1_output_root_mean_squared_error: 3.2237 - val_y2_output_root_mean_squared_error: 4.0492
# Epoch 6/500
# 614/614 [==============================] - 0s 171us/sample - loss: 24.1336 - y1_output_loss: 9.4100 - y2_output_loss: 15.1299 - y1_output_root_mean_squared_error: 3.0359 - y2_output_root_mean_squared_error: 3.8622 - val_loss: 23.9256 - val_y1_output_loss: 8.9202 - val_y2_output_loss: 14.2494 - val_y1_output_root_mean_squared_error: 3.0331 - val_y2_output_root_mean_squared_error: 3.8374
# Epoch 7/500
# 614/614 [==============================] - 0s 166us/sample - loss: 21.3507 - y1_output_loss: 8.8042 - y2_output_loss: 12.4861 - y1_output_root_mean_squared_error: 2.9757 - y2_output_root_mean_squared_error: 3.5350 - val_loss: 31.9156 - val_y1_output_loss: 9.5241 - val_y2_output_loss: 21.4315 - val_y1_output_root_mean_squared_error: 3.1370 - val_y2_output_root_mean_squared_error: 4.6984
# Epoch 8/500
# 614/614 [==============================] - 0s 163us/sample - loss: 21.2942 - y1_output_loss: 8.4459 - y2_output_loss: 12.8736 - y1_output_root_mean_squared_error: 2.9007 - y2_output_root_mean_squared_error: 3.5889 - val_loss: 23.8344 - val_y1_output_loss: 9.2842 - val_y2_output_loss: 13.7845 - val_y1_output_root_mean_squared_error: 3.0983 - val_y2_output_root_mean_squared_error: 3.7729
# Epoch 9/500
# 614/614 [==============================] - 0s 160us/sample - loss: 21.3433 - y1_output_loss: 8.4953 - y2_output_loss: 12.9767 - y1_output_root_mean_squared_error: 2.9057 - y2_output_root_mean_squared_error: 3.5917 - val_loss: 24.8063 - val_y1_output_loss: 9.5991 - val_y2_output_loss: 14.3702 - val_y1_output_root_mean_squared_error: 3.1520 - val_y2_output_root_mean_squared_error: 3.8563
# Epoch 10/500
# 614/614 [==============================] - 0s 155us/sample - loss: 19.1372 - y1_output_loss: 8.0713 - y2_output_loss: 11.6735 - y1_output_root_mean_squared_error: 2.8027 - y2_output_root_mean_squared_error: 3.3589 - val_loss: 275.6623 - val_y1_output_loss: 38.5831 - val_y2_output_loss: 231.1548 - val_y1_output_root_mean_squared_error: 6.2871 - val_y2_output_root_mean_squared_error: 15.3667
# Epoch 11/500
# 614/614 [==============================] - 0s 159us/sample - loss: 29.0637 - y1_output_loss: 9.3967 - y2_output_loss: 19.4796 - y1_output_root_mean_squared_error: 3.0710 - y2_output_root_mean_squared_error: 4.4309 - val_loss: 27.3340 - val_y1_output_loss: 8.7040 - val_y2_output_loss: 17.9074 - val_y1_output_root_mean_squared_error: 2.9927 - val_y2_output_root_mean_squared_error: 4.2870
# Epoch 12/500
# 614/614 [==============================] - 0s 171us/sample - loss: 21.3251 - y1_output_loss: 8.1585 - y2_output_loss: 13.1197 - y1_output_root_mean_squared_error: 2.8671 - y2_output_root_mean_squared_error: 3.6200 - val_loss: 28.1776 - val_y1_output_loss: 10.7843 - val_y2_output_loss: 16.6108 - val_y1_output_root_mean_squared_error: 3.3370 - val_y2_output_root_mean_squared_error: 4.1282
# Epoch 13/500
# 614/614 [==============================] - 0s 159us/sample - loss: 20.4894 - y1_output_loss: 8.0833 - y2_output_loss: 12.2381 - y1_output_root_mean_squared_error: 2.8535 - y2_output_root_mean_squared_error: 3.5138 - val_loss: 21.4693 - val_y1_output_loss: 7.8414 - val_y2_output_loss: 13.0878 - val_y1_output_root_mean_squared_error: 2.8405 - val_y2_output_root_mean_squared_error: 3.6607
# Epoch 14/500
# 614/614 [==============================] - 0s 160us/sample - loss: 22.5303 - y1_output_loss: 8.3686 - y2_output_loss: 14.5245 - y1_output_root_mean_squared_error: 2.8699 - y2_output_root_mean_squared_error: 3.7808 - val_loss: 48.0096 - val_y1_output_loss: 11.8739 - val_y2_output_loss: 34.9900 - val_y1_output_root_mean_squared_error: 3.4906 - val_y2_output_root_mean_squared_error: 5.9854
# Epoch 15/500
# 614/614 [==============================] - 0s 174us/sample - loss: 18.7956 - y1_output_loss: 7.4973 - y2_output_loss: 11.3305 - y1_output_root_mean_squared_error: 2.7249 - y2_output_root_mean_squared_error: 3.3720 - val_loss: 32.8645 - val_y1_output_loss: 12.8672 - val_y2_output_loss: 19.0682 - val_y1_output_root_mean_squared_error: 3.6344 - val_y2_output_root_mean_squared_error: 4.4335
# Epoch 16/500
# 614/614 [==============================] - 0s 168us/sample - loss: 17.8629 - y1_output_loss: 7.0403 - y2_output_loss: 10.7307 - y1_output_root_mean_squared_error: 2.6619 - y2_output_root_mean_squared_error: 3.2829 - val_loss: 22.2187 - val_y1_output_loss: 7.5960 - val_y2_output_loss: 13.9548 - val_y1_output_root_mean_squared_error: 2.8010 - val_y2_output_root_mean_squared_error: 3.7912
# Epoch 17/500
# 614/614 [==============================] - 0s 165us/sample - loss: 16.8079 - y1_output_loss: 6.8463 - y2_output_loss: 9.8324 - y1_output_root_mean_squared_error: 2.6275 - y2_output_root_mean_squared_error: 3.1471 - val_loss: 19.2012 - val_y1_output_loss: 7.6259 - val_y2_output_loss: 11.1005 - val_y1_output_root_mean_squared_error: 2.8018 - val_y2_output_root_mean_squared_error: 3.3691
# Epoch 18/500
# 614/614 [==============================] - 0s 169us/sample - loss: 17.0664 - y1_output_loss: 6.7899 - y2_output_loss: 10.2086 - y1_output_root_mean_squared_error: 2.6159 - y2_output_root_mean_squared_error: 3.1974 - val_loss: 19.6014 - val_y1_output_loss: 7.3250 - val_y2_output_loss: 11.7044 - val_y1_output_root_mean_squared_error: 2.7388 - val_y2_output_root_mean_squared_error: 3.4785
# Epoch 19/500
# 614/614 [==============================] - 0s 162us/sample - loss: 16.2736 - y1_output_loss: 6.3474 - y2_output_loss: 9.8275 - y1_output_root_mean_squared_error: 2.5272 - y2_output_root_mean_squared_error: 3.1443 - val_loss: 20.4619 - val_y1_output_loss: 7.9547 - val_y2_output_loss: 11.8949 - val_y1_output_root_mean_squared_error: 2.8588 - val_y2_output_root_mean_squared_error: 3.5056
# Epoch 20/500
# 614/614 [==============================] - 0s 155us/sample - loss: 20.0824 - y1_output_loss: 7.2143 - y2_output_loss: 13.1186 - y1_output_root_mean_squared_error: 2.6672 - y2_output_root_mean_squared_error: 3.6012 - val_loss: 22.6758 - val_y1_output_loss: 7.5205 - val_y2_output_loss: 14.5408 - val_y1_output_root_mean_squared_error: 2.7825 - val_y2_output_root_mean_squared_error: 3.8644
# Epoch 21/500
# 614/614 [==============================] - 0s 153us/sample - loss: 18.8869 - y1_output_loss: 6.9618 - y2_output_loss: 11.7800 - y1_output_root_mean_squared_error: 2.6502 - y2_output_root_mean_squared_error: 3.4443 - val_loss: 21.4076 - val_y1_output_loss: 7.1230 - val_y2_output_loss: 13.7796 - val_y1_output_root_mean_squared_error: 2.7016 - val_y2_output_root_mean_squared_error: 3.7562
# Epoch 22/500
# 614/614 [==============================] - 0s 158us/sample - loss: 17.4035 - y1_output_loss: 6.4523 - y2_output_loss: 10.8360 - y1_output_root_mean_squared_error: 2.5492 - y2_output_root_mean_squared_error: 3.3023 - val_loss: 18.1657 - val_y1_output_loss: 6.7870 - val_y2_output_loss: 10.7764 - val_y1_output_root_mean_squared_error: 2.6492 - val_y2_output_root_mean_squared_error: 3.3388
# Epoch 23/500
# 614/614 [==============================] - 0s 162us/sample - loss: 19.7208 - y1_output_loss: 6.9370 - y2_output_loss: 12.6804 - y1_output_root_mean_squared_error: 2.6381 - y2_output_root_mean_squared_error: 3.5723 - val_loss: 23.7741 - val_y1_output_loss: 9.1983 - val_y2_output_loss: 13.9441 - val_y1_output_root_mean_squared_error: 3.0804 - val_y2_output_root_mean_squared_error: 3.7796
# Epoch 24/500
# 614/614 [==============================] - 0s 161us/sample - loss: 14.5237 - y1_output_loss: 5.8627 - y2_output_loss: 8.6243 - y1_output_root_mean_squared_error: 2.4262 - y2_output_root_mean_squared_error: 2.9389 - val_loss: 17.6095 - val_y1_output_loss: 6.3466 - val_y2_output_loss: 10.7110 - val_y1_output_root_mean_squared_error: 2.5590 - val_y2_output_root_mean_squared_error: 3.3258
# Epoch 25/500
# 614/614 [==============================] - 0s 162us/sample - loss: 13.1268 - y1_output_loss: 5.4045 - y2_output_loss: 7.8223 - y1_output_root_mean_squared_error: 2.3135 - y2_output_root_mean_squared_error: 2.7883 - val_loss: 29.5998 - val_y1_output_loss: 7.9887 - val_y2_output_loss: 20.8289 - val_y1_output_root_mean_squared_error: 2.8674 - val_y2_output_root_mean_squared_error: 4.6236
# Epoch 26/500
# 614/614 [==============================] - 0s 165us/sample - loss: 15.3088 - y1_output_loss: 5.9074 - y2_output_loss: 9.3924 - y1_output_root_mean_squared_error: 2.4370 - y2_output_root_mean_squared_error: 3.0610 - val_loss: 41.5095 - val_y1_output_loss: 11.9152 - val_y2_output_loss: 28.5941 - val_y1_output_root_mean_squared_error: 3.5037 - val_y2_output_root_mean_squared_error: 5.4068
# Epoch 27/500
# 614/614 [==============================] - 0s 164us/sample - loss: 13.4070 - y1_output_loss: 5.2847 - y2_output_loss: 8.0599 - y1_output_root_mean_squared_error: 2.3033 - y2_output_root_mean_squared_error: 2.8464 - val_loss: 18.3720 - val_y1_output_loss: 5.2801 - val_y2_output_loss: 12.5159 - val_y1_output_root_mean_squared_error: 2.3399 - val_y2_output_root_mean_squared_error: 3.5912
# Epoch 28/500
# 614/614 [==============================] - 0s 156us/sample - loss: 15.9223 - y1_output_loss: 6.0049 - y2_output_loss: 9.9736 - y1_output_root_mean_squared_error: 2.4499 - y2_output_root_mean_squared_error: 3.1496 - val_loss: 18.2812 - val_y1_output_loss: 6.1773 - val_y2_output_loss: 11.4901 - val_y1_output_root_mean_squared_error: 2.5289 - val_y2_output_root_mean_squared_error: 3.4476
# Epoch 29/500
# 614/614 [==============================] - 0s 172us/sample - loss: 17.3615 - y1_output_loss: 6.0393 - y2_output_loss: 11.3142 - y1_output_root_mean_squared_error: 2.4614 - y2_output_root_mean_squared_error: 3.3620 - val_loss: 52.5989 - val_y1_output_loss: 12.0738 - val_y2_output_loss: 39.5496 - val_y1_output_root_mean_squared_error: 3.5181 - val_y2_output_root_mean_squared_error: 6.3421
# Epoch 30/500
# 614/614 [==============================] - 0s 163us/sample - loss: 13.0716 - y1_output_loss: 5.0136 - y2_output_loss: 8.0495 - y1_output_root_mean_squared_error: 2.2280 - y2_output_root_mean_squared_error: 2.8474 - val_loss: 20.2327 - val_y1_output_loss: 7.7599 - val_y2_output_loss: 11.9178 - val_y1_output_root_mean_squared_error: 2.8154 - val_y2_output_root_mean_squared_error: 3.5080
# Epoch 31/500
# 614/614 [==============================] - 0s 160us/sample - loss: 12.8056 - y1_output_loss: 4.9706 - y2_output_loss: 7.7810 - y1_output_root_mean_squared_error: 2.2275 - y2_output_root_mean_squared_error: 2.8007 - val_loss: 14.3776 - val_y1_output_loss: 4.9739 - val_y2_output_loss: 8.9160 - val_y1_output_root_mean_squared_error: 2.2702 - val_y2_output_root_mean_squared_error: 3.0371
# Epoch 32/500
# 614/614 [==============================] - 0s 158us/sample - loss: 13.4674 - y1_output_loss: 4.9883 - y2_output_loss: 8.3523 - y1_output_root_mean_squared_error: 2.2436 - y2_output_root_mean_squared_error: 2.9041 - val_loss: 12.8300 - val_y1_output_loss: 4.4710 - val_y2_output_loss: 7.9553 - val_y1_output_root_mean_squared_error: 2.1520 - val_y2_output_root_mean_squared_error: 2.8634
# Epoch 33/500
# 614/614 [==============================] - 0s 161us/sample - loss: 12.7201 - y1_output_loss: 4.4631 - y2_output_loss: 8.1395 - y1_output_root_mean_squared_error: 2.1223 - y2_output_root_mean_squared_error: 2.8663 - val_loss: 12.9726 - val_y1_output_loss: 4.1148 - val_y2_output_loss: 8.4312 - val_y1_output_root_mean_squared_error: 2.0647 - val_y2_output_root_mean_squared_error: 2.9512
# Epoch 34/500
# 614/614 [==============================] - 0s 161us/sample - loss: 13.6454 - y1_output_loss: 4.7564 - y2_output_loss: 8.9302 - y1_output_root_mean_squared_error: 2.1756 - y2_output_root_mean_squared_error: 2.9853 - val_loss: 14.4149 - val_y1_output_loss: 5.3665 - val_y2_output_loss: 8.7473 - val_y1_output_root_mean_squared_error: 2.3486 - val_y2_output_root_mean_squared_error: 2.9831
# Epoch 35/500
# 614/614 [==============================] - 0s 154us/sample - loss: 10.2034 - y1_output_loss: 3.9475 - y2_output_loss: 6.3034 - y1_output_root_mean_squared_error: 1.9733 - y2_output_root_mean_squared_error: 2.5119 - val_loss: 16.5958 - val_y1_output_loss: 4.5352 - val_y2_output_loss: 11.5689 - val_y1_output_root_mean_squared_error: 2.1646 - val_y2_output_root_mean_squared_error: 3.4511
# Epoch 36/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.9106 - y1_output_loss: 3.8648 - y2_output_loss: 7.4445 - y1_output_root_mean_squared_error: 1.9587 - y2_output_root_mean_squared_error: 2.6597 - val_loss: 110.0441 - val_y1_output_loss: 24.1765 - val_y2_output_loss: 84.9638 - val_y1_output_root_mean_squared_error: 4.9380 - val_y2_output_root_mean_squared_error: 9.2553
# Epoch 37/500
# 614/614 [==============================] - 0s 156us/sample - loss: 14.9106 - y1_output_loss: 4.8798 - y2_output_loss: 10.0391 - y1_output_root_mean_squared_error: 2.2083 - y2_output_root_mean_squared_error: 3.1677 - val_loss: 17.1301 - val_y1_output_loss: 5.1002 - val_y2_output_loss: 11.5401 - val_y1_output_root_mean_squared_error: 2.2928 - val_y2_output_root_mean_squared_error: 3.4457
# Epoch 38/500
# 614/614 [==============================] - 0s 160us/sample - loss: 10.6933 - y1_output_loss: 4.0480 - y2_output_loss: 6.5749 - y1_output_root_mean_squared_error: 2.0169 - y2_output_root_mean_squared_error: 2.5740 - val_loss: 11.0298 - val_y1_output_loss: 3.6373 - val_y2_output_loss: 7.0426 - val_y1_output_root_mean_squared_error: 1.9418 - val_y2_output_root_mean_squared_error: 2.6943
# Epoch 39/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.2427 - y1_output_loss: 3.5312 - y2_output_loss: 5.6623 - y1_output_root_mean_squared_error: 1.8822 - y2_output_root_mean_squared_error: 2.3875 - val_loss: 10.2491 - val_y1_output_loss: 3.4793 - val_y2_output_loss: 6.4655 - val_y1_output_root_mean_squared_error: 1.8978 - val_y2_output_root_mean_squared_error: 2.5783
# Epoch 40/500
# 614/614 [==============================] - 0s 164us/sample - loss: 9.4773 - y1_output_loss: 3.2352 - y2_output_loss: 6.2872 - y1_output_root_mean_squared_error: 1.7880 - y2_output_root_mean_squared_error: 2.5060 - val_loss: 9.6492 - val_y1_output_loss: 3.3389 - val_y2_output_loss: 6.0480 - val_y1_output_root_mean_squared_error: 1.8587 - val_y2_output_root_mean_squared_error: 2.4889
# Epoch 41/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.6404 - y1_output_loss: 3.1341 - y2_output_loss: 5.4587 - y1_output_root_mean_squared_error: 1.7771 - y2_output_root_mean_squared_error: 2.3415 - val_loss: 9.1300 - val_y1_output_loss: 3.0351 - val_y2_output_loss: 5.7740 - val_y1_output_root_mean_squared_error: 1.7715 - val_y2_output_root_mean_squared_error: 2.4478
# Epoch 42/500
# 614/614 [==============================] - 0s 165us/sample - loss: 8.3084 - y1_output_loss: 2.9274 - y2_output_loss: 5.3592 - y1_output_root_mean_squared_error: 1.7110 - y2_output_root_mean_squared_error: 2.3196 - val_loss: 9.8590 - val_y1_output_loss: 3.4839 - val_y2_output_loss: 6.2251 - val_y1_output_root_mean_squared_error: 1.8882 - val_y2_output_root_mean_squared_error: 2.5087
# Epoch 43/500
# 614/614 [==============================] - 0s 157us/sample - loss: 8.9966 - y1_output_loss: 2.9927 - y2_output_loss: 6.1139 - y1_output_root_mean_squared_error: 1.7290 - y2_output_root_mean_squared_error: 2.4510 - val_loss: 31.7191 - val_y1_output_loss: 9.2413 - val_y2_output_loss: 21.4245 - val_y1_output_root_mean_squared_error: 3.0970 - val_y2_output_root_mean_squared_error: 4.7040
# Epoch 44/500
# 614/614 [==============================] - 0s 162us/sample - loss: 9.3978 - y1_output_loss: 3.2238 - y2_output_loss: 6.1360 - y1_output_root_mean_squared_error: 1.7969 - y2_output_root_mean_squared_error: 2.4838 - val_loss: 7.7076 - val_y1_output_loss: 2.3229 - val_y2_output_loss: 5.1174 - val_y1_output_root_mean_squared_error: 1.5527 - val_y2_output_root_mean_squared_error: 2.3015
# Epoch 45/500
# 614/614 [==============================] - 0s 164us/sample - loss: 8.5248 - y1_output_loss: 2.7722 - y2_output_loss: 5.6957 - y1_output_root_mean_squared_error: 1.6688 - y2_output_root_mean_squared_error: 2.3958 - val_loss: 10.2659 - val_y1_output_loss: 2.9809 - val_y2_output_loss: 7.1018 - val_y1_output_root_mean_squared_error: 1.7515 - val_y2_output_root_mean_squared_error: 2.6829
# Epoch 46/500
# 614/614 [==============================] - 0s 164us/sample - loss: 7.8320 - y1_output_loss: 2.7706 - y2_output_loss: 5.4058 - y1_output_root_mean_squared_error: 1.6217 - y2_output_root_mean_squared_error: 2.2808 - val_loss: 65.8618 - val_y1_output_loss: 19.7969 - val_y2_output_loss: 44.8647 - val_y1_output_root_mean_squared_error: 4.4715 - val_y2_output_root_mean_squared_error: 6.7726
# Epoch 47/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.5453 - y1_output_loss: 2.9814 - y2_output_loss: 6.5120 - y1_output_root_mean_squared_error: 1.7336 - y2_output_root_mean_squared_error: 2.5573 - val_loss: 11.2704 - val_y1_output_loss: 3.4048 - val_y2_output_loss: 7.8079 - val_y1_output_root_mean_squared_error: 1.8579 - val_y2_output_root_mean_squared_error: 2.7962
# Epoch 48/500
# 614/614 [==============================] - 0s 158us/sample - loss: 7.2243 - y1_output_loss: 2.4317 - y2_output_loss: 4.7305 - y1_output_root_mean_squared_error: 1.5648 - y2_output_root_mean_squared_error: 2.1854 - val_loss: 7.5853 - val_y1_output_loss: 2.3072 - val_y2_output_loss: 5.0540 - val_y1_output_root_mean_squared_error: 1.5451 - val_y2_output_root_mean_squared_error: 2.2799
# Epoch 49/500
# 614/614 [==============================] - 0s 160us/sample - loss: 6.9824 - y1_output_loss: 2.2600 - y2_output_loss: 4.6944 - y1_output_root_mean_squared_error: 1.5057 - y2_output_root_mean_squared_error: 2.1715 - val_loss: 11.1080 - val_y1_output_loss: 2.5563 - val_y2_output_loss: 8.1855 - val_y1_output_root_mean_squared_error: 1.6258 - val_y2_output_root_mean_squared_error: 2.9094
# Epoch 50/500
# 614/614 [==============================] - 0s 161us/sample - loss: 7.1225 - y1_output_loss: 2.2335 - y2_output_loss: 4.8535 - y1_output_root_mean_squared_error: 1.4915 - y2_output_root_mean_squared_error: 2.2131 - val_loss: 7.6365 - val_y1_output_loss: 2.1101 - val_y2_output_loss: 5.3271 - val_y1_output_root_mean_squared_error: 1.4756 - val_y2_output_root_mean_squared_error: 2.3365
# Epoch 51/500
# 614/614 [==============================] - 0s 170us/sample - loss: 7.3096 - y1_output_loss: 2.1356 - y2_output_loss: 5.1675 - y1_output_root_mean_squared_error: 1.4669 - y2_output_root_mean_squared_error: 2.2711 - val_loss: 12.6677 - val_y1_output_loss: 4.2238 - val_y2_output_loss: 8.0080 - val_y1_output_root_mean_squared_error: 2.0911 - val_y2_output_root_mean_squared_error: 2.8801
# Epoch 52/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.2429 - y1_output_loss: 1.7831 - y2_output_loss: 4.4459 - y1_output_root_mean_squared_error: 1.3344 - y2_output_root_mean_squared_error: 2.1124 - val_loss: 7.5124 - val_y1_output_loss: 2.5358 - val_y2_output_loss: 4.8200 - val_y1_output_root_mean_squared_error: 1.6113 - val_y2_output_root_mean_squared_error: 2.2172
# Epoch 53/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.7566 - y1_output_loss: 2.9299 - y2_output_loss: 6.8269 - y1_output_root_mean_squared_error: 1.6980 - y2_output_root_mean_squared_error: 2.6217 - val_loss: 6.9362 - val_y1_output_loss: 1.8271 - val_y2_output_loss: 4.8745 - val_y1_output_root_mean_squared_error: 1.3757 - val_y2_output_root_mean_squared_error: 2.2458
# Epoch 54/500
# 614/614 [==============================] - 0s 164us/sample - loss: 5.8551 - y1_output_loss: 1.6400 - y2_output_loss: 4.1695 - y1_output_root_mean_squared_error: 1.2858 - y2_output_root_mean_squared_error: 2.0499 - val_loss: 6.3081 - val_y1_output_loss: 1.9278 - val_y2_output_loss: 4.1619 - val_y1_output_root_mean_squared_error: 1.4136 - val_y2_output_root_mean_squared_error: 2.0760
# Epoch 55/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.6790 - y1_output_loss: 1.9838 - y2_output_loss: 4.7572 - y1_output_root_mean_squared_error: 1.3955 - y2_output_root_mean_squared_error: 2.1752 - val_loss: 15.9709 - val_y1_output_loss: 3.7854 - val_y2_output_loss: 11.6471 - val_y1_output_root_mean_squared_error: 1.9800 - val_y2_output_root_mean_squared_error: 3.4714
# Epoch 56/500
# 614/614 [==============================] - 0s 165us/sample - loss: 5.7079 - y1_output_loss: 1.7238 - y2_output_loss: 4.0228 - y1_output_root_mean_squared_error: 1.3025 - y2_output_root_mean_squared_error: 2.0028 - val_loss: 16.9160 - val_y1_output_loss: 4.9160 - val_y2_output_loss: 11.4409 - val_y1_output_root_mean_squared_error: 2.2484 - val_y2_output_root_mean_squared_error: 3.4439
# Epoch 57/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.3781 - y1_output_loss: 1.5354 - y2_output_loss: 3.8838 - y1_output_root_mean_squared_error: 1.2380 - y2_output_root_mean_squared_error: 1.9610 - val_loss: 7.5481 - val_y1_output_loss: 2.2104 - val_y2_output_loss: 5.1154 - val_y1_output_root_mean_squared_error: 1.5057 - val_y2_output_root_mean_squared_error: 2.2980
# Epoch 58/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.9916 - y1_output_loss: 1.7604 - y2_output_loss: 4.2196 - y1_output_root_mean_squared_error: 1.3257 - y2_output_root_mean_squared_error: 2.0577 - val_loss: 8.5948 - val_y1_output_loss: 2.8784 - val_y2_output_loss: 5.5021 - val_y1_output_root_mean_squared_error: 1.7033 - val_y2_output_root_mean_squared_error: 2.3861
# Epoch 59/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.8154 - y1_output_loss: 1.6037 - y2_output_loss: 4.2298 - y1_output_root_mean_squared_error: 1.2635 - y2_output_root_mean_squared_error: 2.0540 - val_loss: 22.6910 - val_y1_output_loss: 6.7258 - val_y2_output_loss: 15.2152 - val_y1_output_root_mean_squared_error: 2.6404 - val_y2_output_root_mean_squared_error: 3.9647
# Epoch 60/500
# 614/614 [==============================] - 0s 175us/sample - loss: 5.1838 - y1_output_loss: 1.4354 - y2_output_loss: 3.7393 - y1_output_root_mean_squared_error: 1.1953 - y2_output_root_mean_squared_error: 1.9378 - val_loss: 9.8803 - val_y1_output_loss: 2.1860 - val_y2_output_loss: 7.6125 - val_y1_output_root_mean_squared_error: 1.4958 - val_y2_output_root_mean_squared_error: 2.7646
# Epoch 61/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.5742 - y1_output_loss: 1.4144 - y2_output_loss: 4.1788 - y1_output_root_mean_squared_error: 1.1887 - y2_output_root_mean_squared_error: 2.0399 - val_loss: 11.8861 - val_y1_output_loss: 4.3164 - val_y2_output_loss: 7.4102 - val_y1_output_root_mean_squared_error: 2.0987 - val_y2_output_root_mean_squared_error: 2.7352
# Epoch 62/500
# 614/614 [==============================] - 0s 174us/sample - loss: 8.4629 - y1_output_loss: 2.3952 - y2_output_loss: 6.0212 - y1_output_root_mean_squared_error: 1.5438 - y2_output_root_mean_squared_error: 2.4657 - val_loss: 5.9496 - val_y1_output_loss: 1.3608 - val_y2_output_loss: 4.3820 - val_y1_output_root_mean_squared_error: 1.1845 - val_y2_output_root_mean_squared_error: 2.1323
# Epoch 63/500
# 614/614 [==============================] - 0s 164us/sample - loss: 5.2716 - y1_output_loss: 1.4193 - y2_output_loss: 3.8901 - y1_output_root_mean_squared_error: 1.1964 - y2_output_root_mean_squared_error: 1.9597 - val_loss: 9.7089 - val_y1_output_loss: 1.5793 - val_y2_output_loss: 7.8271 - val_y1_output_root_mean_squared_error: 1.2698 - val_y2_output_root_mean_squared_error: 2.8454
# Epoch 64/500
# 614/614 [==============================] - 0s 158us/sample - loss: 4.8382 - y1_output_loss: 1.1521 - y2_output_loss: 3.7016 - y1_output_root_mean_squared_error: 1.0748 - y2_output_root_mean_squared_error: 1.9191 - val_loss: 8.2565 - val_y1_output_loss: 2.3076 - val_y2_output_loss: 5.7893 - val_y1_output_root_mean_squared_error: 1.5295 - val_y2_output_root_mean_squared_error: 2.4325
# Epoch 65/500
# 614/614 [==============================] - 0s 166us/sample - loss: 4.2742 - y1_output_loss: 1.1056 - y2_output_loss: 3.1436 - y1_output_root_mean_squared_error: 1.0559 - y2_output_root_mean_squared_error: 1.7775 - val_loss: 6.1491 - val_y1_output_loss: 1.5319 - val_y2_output_loss: 4.4277 - val_y1_output_root_mean_squared_error: 1.2526 - val_y2_output_root_mean_squared_error: 2.1401
# Epoch 66/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.0180 - y1_output_loss: 1.5281 - y2_output_loss: 4.4621 - y1_output_root_mean_squared_error: 1.2361 - y2_output_root_mean_squared_error: 2.1189 - val_loss: 6.2610 - val_y1_output_loss: 1.4488 - val_y2_output_loss: 4.7142 - val_y1_output_root_mean_squared_error: 1.2196 - val_y2_output_root_mean_squared_error: 2.1849
# Epoch 67/500
# 614/614 [==============================] - 0s 169us/sample - loss: 4.8838 - y1_output_loss: 1.2163 - y2_output_loss: 3.6977 - y1_output_root_mean_squared_error: 1.1000 - y2_output_root_mean_squared_error: 1.9167 - val_loss: 14.0186 - val_y1_output_loss: 4.3507 - val_y2_output_loss: 9.4236 - val_y1_output_root_mean_squared_error: 2.1076 - val_y2_output_root_mean_squared_error: 3.0946
# Epoch 68/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.7153 - y1_output_loss: 1.5360 - y2_output_loss: 4.2118 - y1_output_root_mean_squared_error: 1.2380 - y2_output_root_mean_squared_error: 2.0451 - val_loss: 7.3409 - val_y1_output_loss: 1.3996 - val_y2_output_loss: 5.8093 - val_y1_output_root_mean_squared_error: 1.2013 - val_y2_output_root_mean_squared_error: 2.4285
# Epoch 69/500
# 614/614 [==============================] - 0s 165us/sample - loss: 4.1361 - y1_output_loss: 1.0031 - y2_output_loss: 3.1203 - y1_output_root_mean_squared_error: 1.0021 - y2_output_root_mean_squared_error: 1.7697 - val_loss: 7.6313 - val_y1_output_loss: 2.2536 - val_y2_output_loss: 5.3921 - val_y1_output_root_mean_squared_error: 1.5023 - val_y2_output_root_mean_squared_error: 2.3183
# Epoch 70/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.9081 - y1_output_loss: 0.8807 - y2_output_loss: 2.9926 - y1_output_root_mean_squared_error: 0.9424 - y2_output_root_mean_squared_error: 1.7378 - val_loss: 4.2624 - val_y1_output_loss: 0.9180 - val_y2_output_loss: 3.2154 - val_y1_output_root_mean_squared_error: 0.9702 - val_y2_output_root_mean_squared_error: 1.8224
# Epoch 71/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.1370 - y1_output_loss: 1.4022 - y2_output_loss: 3.8591 - y1_output_root_mean_squared_error: 1.1494 - y2_output_root_mean_squared_error: 1.9534 - val_loss: 15.4942 - val_y1_output_loss: 7.3813 - val_y2_output_loss: 7.8088 - val_y1_output_root_mean_squared_error: 2.7496 - val_y2_output_root_mean_squared_error: 2.8167
# Epoch 72/500
# 614/614 [==============================] - 0s 168us/sample - loss: 5.6062 - y1_output_loss: 1.4415 - y2_output_loss: 4.1336 - y1_output_root_mean_squared_error: 1.2050 - y2_output_root_mean_squared_error: 2.0382 - val_loss: 5.2368 - val_y1_output_loss: 1.1024 - val_y2_output_loss: 3.9581 - val_y1_output_root_mean_squared_error: 1.0672 - val_y2_output_root_mean_squared_error: 2.0243
# Epoch 73/500
# 614/614 [==============================] - 0s 168us/sample - loss: 5.1349 - y1_output_loss: 1.1509 - y2_output_loss: 3.9614 - y1_output_root_mean_squared_error: 1.0684 - y2_output_root_mean_squared_error: 1.9984 - val_loss: 4.5556 - val_y1_output_loss: 0.9637 - val_y2_output_loss: 3.4374 - val_y1_output_root_mean_squared_error: 0.9979 - val_y2_output_root_mean_squared_error: 1.8867
# Epoch 74/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.3316 - y1_output_loss: 0.9503 - y2_output_loss: 3.4169 - y1_output_root_mean_squared_error: 0.9785 - y2_output_root_mean_squared_error: 1.8369 - val_loss: 6.2281 - val_y1_output_loss: 1.0860 - val_y2_output_loss: 5.0014 - val_y1_output_root_mean_squared_error: 1.0532 - val_y2_output_root_mean_squared_error: 2.2625
# Epoch 75/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.8708 - y1_output_loss: 1.0732 - y2_output_loss: 3.7747 - y1_output_root_mean_squared_error: 1.0380 - y2_output_root_mean_squared_error: 1.9477 - val_loss: 6.3310 - val_y1_output_loss: 1.2778 - val_y2_output_loss: 4.8705 - val_y1_output_root_mean_squared_error: 1.1329 - val_y2_output_root_mean_squared_error: 2.2467
# Epoch 76/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.0535 - y1_output_loss: 1.3783 - y2_output_loss: 4.6446 - y1_output_root_mean_squared_error: 1.1753 - y2_output_root_mean_squared_error: 2.1615 - val_loss: 4.9018 - val_y1_output_loss: 0.9404 - val_y2_output_loss: 3.7956 - val_y1_output_root_mean_squared_error: 0.9855 - val_y2_output_root_mean_squared_error: 1.9826
# Epoch 77/500
# 614/614 [==============================] - 0s 165us/sample - loss: 4.3473 - y1_output_loss: 1.0993 - y2_output_loss: 3.2409 - y1_output_root_mean_squared_error: 1.0427 - y2_output_root_mean_squared_error: 1.8056 - val_loss: 4.7794 - val_y1_output_loss: 1.1192 - val_y2_output_loss: 3.5027 - val_y1_output_root_mean_squared_error: 1.0737 - val_y2_output_root_mean_squared_error: 1.9043
# Epoch 78/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.1922 - y1_output_loss: 0.7711 - y2_output_loss: 2.6102 - y1_output_root_mean_squared_error: 0.8673 - y2_output_root_mean_squared_error: 1.5621 - val_loss: 34.8464 - val_y1_output_loss: 8.6557 - val_y2_output_loss: 25.4725 - val_y1_output_root_mean_squared_error: 2.9798 - val_y2_output_root_mean_squared_error: 5.0958
# Epoch 79/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.2011 - y1_output_loss: 0.9651 - y2_output_loss: 3.2160 - y1_output_root_mean_squared_error: 0.9846 - y2_output_root_mean_squared_error: 1.7977 - val_loss: 7.1886 - val_y1_output_loss: 1.0532 - val_y2_output_loss: 5.8979 - val_y1_output_root_mean_squared_error: 1.0459 - val_y2_output_root_mean_squared_error: 2.4687
# Epoch 80/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.8606 - y1_output_loss: 0.7971 - y2_output_loss: 3.0724 - y1_output_root_mean_squared_error: 0.8926 - y2_output_root_mean_squared_error: 1.7504 - val_loss: 4.9030 - val_y1_output_loss: 1.4364 - val_y2_output_loss: 3.3424 - val_y1_output_root_mean_squared_error: 1.2089 - val_y2_output_root_mean_squared_error: 1.8552
# Epoch 81/500
# 614/614 [==============================] - 0s 179us/sample - loss: 4.2553 - y1_output_loss: 0.9849 - y2_output_loss: 3.2303 - y1_output_root_mean_squared_error: 0.9968 - y2_output_root_mean_squared_error: 1.8060 - val_loss: 3.9277 - val_y1_output_loss: 0.6672 - val_y2_output_loss: 3.1241 - val_y1_output_root_mean_squared_error: 0.8265 - val_y2_output_root_mean_squared_error: 1.8013
# Epoch 82/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.4120 - y1_output_loss: 0.7548 - y2_output_loss: 2.6506 - y1_output_root_mean_squared_error: 0.8618 - y2_output_root_mean_squared_error: 1.6338 - val_loss: 6.8857 - val_y1_output_loss: 2.1085 - val_y2_output_loss: 4.6118 - val_y1_output_root_mean_squared_error: 1.4535 - val_y2_output_root_mean_squared_error: 2.1848
# Epoch 83/500
# 614/614 [==============================] - 0s 170us/sample - loss: 4.7565 - y1_output_loss: 1.1020 - y2_output_loss: 3.6165 - y1_output_root_mean_squared_error: 1.0539 - y2_output_root_mean_squared_error: 1.9094 - val_loss: 5.0275 - val_y1_output_loss: 1.2655 - val_y2_output_loss: 3.6234 - val_y1_output_root_mean_squared_error: 1.1343 - val_y2_output_root_mean_squared_error: 1.9341
# Epoch 84/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.6362 - y1_output_loss: 0.8908 - y2_output_loss: 2.7192 - y1_output_root_mean_squared_error: 0.9456 - y2_output_root_mean_squared_error: 1.6559 - val_loss: 4.4145 - val_y1_output_loss: 0.7998 - val_y2_output_loss: 3.4760 - val_y1_output_root_mean_squared_error: 0.9060 - val_y2_output_root_mean_squared_error: 1.8957
# Epoch 85/500
# 614/614 [==============================] - 0s 169us/sample - loss: 4.5624 - y1_output_loss: 1.0411 - y2_output_loss: 3.5553 - y1_output_root_mean_squared_error: 0.9981 - y2_output_root_mean_squared_error: 1.8885 - val_loss: 20.4630 - val_y1_output_loss: 7.2074 - val_y2_output_loss: 12.7805 - val_y1_output_root_mean_squared_error: 2.7026 - val_y2_output_root_mean_squared_error: 3.6275
# Epoch 86/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.6395 - y1_output_loss: 0.8471 - y2_output_loss: 2.8018 - y1_output_root_mean_squared_error: 0.9211 - y2_output_root_mean_squared_error: 1.6707 - val_loss: 9.9878 - val_y1_output_loss: 1.3202 - val_y2_output_loss: 8.3476 - val_y1_output_root_mean_squared_error: 1.1568 - val_y2_output_root_mean_squared_error: 2.9410
# Epoch 87/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.3305 - y1_output_loss: 0.7430 - y2_output_loss: 2.5701 - y1_output_root_mean_squared_error: 0.8641 - y2_output_root_mean_squared_error: 1.6074 - val_loss: 3.6000 - val_y1_output_loss: 0.8765 - val_y2_output_loss: 2.6131 - val_y1_output_root_mean_squared_error: 0.9410 - val_y2_output_root_mean_squared_error: 1.6475
# Epoch 88/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.8426 - y1_output_loss: 0.6255 - y2_output_loss: 2.2190 - y1_output_root_mean_squared_error: 0.7909 - y2_output_root_mean_squared_error: 1.4890 - val_loss: 5.6580 - val_y1_output_loss: 0.6124 - val_y2_output_loss: 4.8609 - val_y1_output_root_mean_squared_error: 0.7898 - val_y2_output_root_mean_squared_error: 2.2437
# Epoch 89/500
# 614/614 [==============================] - 0s 166us/sample - loss: 3.3755 - y1_output_loss: 0.8206 - y2_output_loss: 2.5260 - y1_output_root_mean_squared_error: 0.9097 - y2_output_root_mean_squared_error: 1.5962 - val_loss: 3.4406 - val_y1_output_loss: 0.6067 - val_y2_output_loss: 2.7299 - val_y1_output_root_mean_squared_error: 0.7888 - val_y2_output_root_mean_squared_error: 1.6788
# Epoch 90/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.2277 - y1_output_loss: 0.6552 - y2_output_loss: 2.5913 - y1_output_root_mean_squared_error: 0.8098 - y2_output_root_mean_squared_error: 1.6037 - val_loss: 5.9567 - val_y1_output_loss: 1.5262 - val_y2_output_loss: 4.2614 - val_y1_output_root_mean_squared_error: 1.2407 - val_y2_output_root_mean_squared_error: 2.1018
# Epoch 91/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.8053 - y1_output_loss: 0.6784 - y2_output_loss: 2.1043 - y1_output_root_mean_squared_error: 0.8265 - y2_output_root_mean_squared_error: 1.4568 - val_loss: 3.1083 - val_y1_output_loss: 0.5572 - val_y2_output_loss: 2.4560 - val_y1_output_root_mean_squared_error: 0.7511 - val_y2_output_root_mean_squared_error: 1.5951
# Epoch 92/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.6189 - y1_output_loss: 0.8017 - y2_output_loss: 2.8256 - y1_output_root_mean_squared_error: 0.8894 - y2_output_root_mean_squared_error: 1.6816 - val_loss: 4.3142 - val_y1_output_loss: 0.8624 - val_y2_output_loss: 3.3675 - val_y1_output_root_mean_squared_error: 0.9445 - val_y2_output_root_mean_squared_error: 1.8499
# Epoch 93/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1011 - y1_output_loss: 0.7043 - y2_output_loss: 2.4309 - y1_output_root_mean_squared_error: 0.8402 - y2_output_root_mean_squared_error: 1.5476 - val_loss: 8.0064 - val_y1_output_loss: 1.6842 - val_y2_output_loss: 6.0777 - val_y1_output_root_mean_squared_error: 1.3105 - val_y2_output_root_mean_squared_error: 2.5078
# Epoch 94/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.7623 - y1_output_loss: 0.7520 - y2_output_loss: 2.9827 - y1_output_root_mean_squared_error: 0.8713 - y2_output_root_mean_squared_error: 1.7330 - val_loss: 7.8307 - val_y1_output_loss: 1.8670 - val_y2_output_loss: 5.7754 - val_y1_output_root_mean_squared_error: 1.3655 - val_y2_output_root_mean_squared_error: 2.4426
# Epoch 95/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.8438 - y1_output_loss: 0.8430 - y2_output_loss: 2.9711 - y1_output_root_mean_squared_error: 0.9202 - y2_output_root_mean_squared_error: 1.7312 - val_loss: 4.3848 - val_y1_output_loss: 0.7683 - val_y2_output_loss: 3.4665 - val_y1_output_root_mean_squared_error: 0.8889 - val_y2_output_root_mean_squared_error: 1.8960
# Epoch 96/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.0710 - y1_output_loss: 0.8825 - y2_output_loss: 3.1747 - y1_output_root_mean_squared_error: 0.9387 - y2_output_root_mean_squared_error: 1.7860 - val_loss: 5.9255 - val_y1_output_loss: 1.8010 - val_y2_output_loss: 4.1210 - val_y1_output_root_mean_squared_error: 1.3442 - val_y2_output_root_mean_squared_error: 2.0294
# Epoch 97/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.1854 - y1_output_loss: 0.7821 - y2_output_loss: 2.4577 - y1_output_root_mean_squared_error: 0.8703 - y2_output_root_mean_squared_error: 1.5582 - val_loss: 21.1615 - val_y1_output_loss: 6.8817 - val_y2_output_loss: 13.9029 - val_y1_output_root_mean_squared_error: 2.6251 - val_y2_output_root_mean_squared_error: 3.7776
# Epoch 98/500
# 614/614 [==============================] - 0s 187us/sample - loss: 2.9679 - y1_output_loss: 0.7185 - y2_output_loss: 2.2564 - y1_output_root_mean_squared_error: 0.8478 - y2_output_root_mean_squared_error: 1.4997 - val_loss: 4.0816 - val_y1_output_loss: 0.4620 - val_y2_output_loss: 3.5820 - val_y1_output_root_mean_squared_error: 0.6921 - val_y2_output_root_mean_squared_error: 1.8981
# Epoch 99/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6771 - y1_output_loss: 0.5507 - y2_output_loss: 2.1770 - y1_output_root_mean_squared_error: 0.7438 - y2_output_root_mean_squared_error: 1.4574 - val_loss: 10.9675 - val_y1_output_loss: 4.1219 - val_y2_output_loss: 6.4790 - val_y1_output_root_mean_squared_error: 2.0671 - val_y2_output_root_mean_squared_error: 2.5874
# Epoch 100/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.3389 - y1_output_loss: 0.7400 - y2_output_loss: 2.5861 - y1_output_root_mean_squared_error: 0.8591 - y2_output_root_mean_squared_error: 1.6127 - val_loss: 3.4340 - val_y1_output_loss: 0.5700 - val_y2_output_loss: 2.7537 - val_y1_output_root_mean_squared_error: 0.7665 - val_y2_output_root_mean_squared_error: 1.6871
# Epoch 101/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.8659 - y1_output_loss: 0.6827 - y2_output_loss: 2.1762 - y1_output_root_mean_squared_error: 0.8238 - y2_output_root_mean_squared_error: 1.4789 - val_loss: 4.8057 - val_y1_output_loss: 1.6181 - val_y2_output_loss: 3.1118 - val_y1_output_root_mean_squared_error: 1.2648 - val_y2_output_root_mean_squared_error: 1.7905
# Epoch 102/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.7536 - y1_output_loss: 0.6354 - y2_output_loss: 2.1073 - y1_output_root_mean_squared_error: 0.7948 - y2_output_root_mean_squared_error: 1.4567 - val_loss: 3.7817 - val_y1_output_loss: 0.8503 - val_y2_output_loss: 2.8434 - val_y1_output_root_mean_squared_error: 0.9131 - val_y2_output_root_mean_squared_error: 1.7170
# Epoch 103/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.8926 - y1_output_loss: 0.6862 - y2_output_loss: 2.2150 - y1_output_root_mean_squared_error: 0.8303 - y2_output_root_mean_squared_error: 1.4843 - val_loss: 7.3209 - val_y1_output_loss: 1.7928 - val_y2_output_loss: 5.3027 - val_y1_output_root_mean_squared_error: 1.3532 - val_y2_output_root_mean_squared_error: 2.3430
# Epoch 104/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.1711 - y1_output_loss: 0.6678 - y2_output_loss: 2.6213 - y1_output_root_mean_squared_error: 0.8185 - y2_output_root_mean_squared_error: 1.5815 - val_loss: 24.9436 - val_y1_output_loss: 4.2232 - val_y2_output_loss: 20.3772 - val_y1_output_root_mean_squared_error: 2.0770 - val_y2_output_root_mean_squared_error: 4.5420
# Epoch 105/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.0699 - y1_output_loss: 0.9144 - y2_output_loss: 3.1443 - y1_output_root_mean_squared_error: 0.9564 - y2_output_root_mean_squared_error: 1.7763 - val_loss: 5.6052 - val_y1_output_loss: 2.1025 - val_y2_output_loss: 3.3366 - val_y1_output_root_mean_squared_error: 1.4684 - val_y2_output_root_mean_squared_error: 1.8571
# Epoch 106/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.8091 - y1_output_loss: 0.6882 - y2_output_loss: 2.1287 - y1_output_root_mean_squared_error: 0.8297 - y2_output_root_mean_squared_error: 1.4563 - val_loss: 10.2613 - val_y1_output_loss: 2.6702 - val_y2_output_loss: 7.5991 - val_y1_output_root_mean_squared_error: 1.6402 - val_y2_output_root_mean_squared_error: 2.7515
# Epoch 107/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.2072 - y1_output_loss: 0.6997 - y2_output_loss: 2.4925 - y1_output_root_mean_squared_error: 0.8375 - y2_output_root_mean_squared_error: 1.5830 - val_loss: 3.4312 - val_y1_output_loss: 0.6879 - val_y2_output_loss: 2.6869 - val_y1_output_root_mean_squared_error: 0.8404 - val_y2_output_root_mean_squared_error: 1.6508
# Epoch 108/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8376 - y1_output_loss: 0.5900 - y2_output_loss: 2.2412 - y1_output_root_mean_squared_error: 0.7716 - y2_output_root_mean_squared_error: 1.4974 - val_loss: 3.4967 - val_y1_output_loss: 0.7056 - val_y2_output_loss: 2.7604 - val_y1_output_root_mean_squared_error: 0.8476 - val_y2_output_root_mean_squared_error: 1.6668
# Epoch 109/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.5363 - y1_output_loss: 0.8083 - y2_output_loss: 2.7295 - y1_output_root_mean_squared_error: 0.9022 - y2_output_root_mean_squared_error: 1.6500 - val_loss: 3.3292 - val_y1_output_loss: 0.5091 - val_y2_output_loss: 2.7090 - val_y1_output_root_mean_squared_error: 0.7242 - val_y2_output_root_mean_squared_error: 1.6747
# Epoch 110/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.4151 - y1_output_loss: 0.7229 - y2_output_loss: 2.6852 - y1_output_root_mean_squared_error: 0.8488 - y2_output_root_mean_squared_error: 1.6416 - val_loss: 3.5989 - val_y1_output_loss: 0.9529 - val_y2_output_loss: 2.5659 - val_y1_output_root_mean_squared_error: 0.9893 - val_y2_output_root_mean_squared_error: 1.6187
# Epoch 111/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4779 - y1_output_loss: 0.5837 - y2_output_loss: 1.8817 - y1_output_root_mean_squared_error: 0.7651 - y2_output_root_mean_squared_error: 1.3757 - val_loss: 2.7698 - val_y1_output_loss: 0.5022 - val_y2_output_loss: 2.2115 - val_y1_output_root_mean_squared_error: 0.7163 - val_y2_output_root_mean_squared_error: 1.5022
# Epoch 112/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.4433 - y1_output_loss: 0.5300 - y2_output_loss: 1.8980 - y1_output_root_mean_squared_error: 0.7311 - y2_output_root_mean_squared_error: 1.3816 - val_loss: 3.7895 - val_y1_output_loss: 0.7976 - val_y2_output_loss: 2.9452 - val_y1_output_root_mean_squared_error: 0.9003 - val_y2_output_root_mean_squared_error: 1.7260
# Epoch 113/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1968 - y1_output_loss: 0.6787 - y2_output_loss: 2.5400 - y1_output_root_mean_squared_error: 0.8246 - y2_output_root_mean_squared_error: 1.5864 - val_loss: 9.1618 - val_y1_output_loss: 2.5517 - val_y2_output_loss: 6.6098 - val_y1_output_root_mean_squared_error: 1.6020 - val_y2_output_root_mean_squared_error: 2.5681
# Epoch 114/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.5620 - y1_output_loss: 0.7814 - y2_output_loss: 2.7832 - y1_output_root_mean_squared_error: 0.8863 - y2_output_root_mean_squared_error: 1.6663 - val_loss: 4.3844 - val_y1_output_loss: 0.7770 - val_y2_output_loss: 3.6038 - val_y1_output_root_mean_squared_error: 0.8860 - val_y2_output_root_mean_squared_error: 1.8972
# Epoch 115/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.5466 - y1_output_loss: 0.7696 - y2_output_loss: 2.7549 - y1_output_root_mean_squared_error: 0.8809 - y2_output_root_mean_squared_error: 1.6645 - val_loss: 3.1914 - val_y1_output_loss: 0.6277 - val_y2_output_loss: 2.4925 - val_y1_output_root_mean_squared_error: 0.7953 - val_y2_output_root_mean_squared_error: 1.5996
# Epoch 116/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.6683 - y1_output_loss: 0.6577 - y2_output_loss: 1.9937 - y1_output_root_mean_squared_error: 0.8125 - y2_output_root_mean_squared_error: 1.4171 - val_loss: 3.0341 - val_y1_output_loss: 0.4914 - val_y2_output_loss: 2.4633 - val_y1_output_root_mean_squared_error: 0.7128 - val_y2_output_root_mean_squared_error: 1.5894
# Epoch 117/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.5179 - y1_output_loss: 0.6003 - y2_output_loss: 1.9479 - y1_output_root_mean_squared_error: 0.7755 - y2_output_root_mean_squared_error: 1.3844 - val_loss: 9.2069 - val_y1_output_loss: 2.4859 - val_y2_output_loss: 6.7831 - val_y1_output_root_mean_squared_error: 1.5752 - val_y2_output_root_mean_squared_error: 2.5934
# Epoch 118/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.8872 - y1_output_loss: 0.6616 - y2_output_loss: 2.2132 - y1_output_root_mean_squared_error: 0.8087 - y2_output_root_mean_squared_error: 1.4944 - val_loss: 3.0275 - val_y1_output_loss: 0.6023 - val_y2_output_loss: 2.3492 - val_y1_output_root_mean_squared_error: 0.7855 - val_y2_output_root_mean_squared_error: 1.5526
# Epoch 119/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.3438 - y1_output_loss: 0.5125 - y2_output_loss: 1.9533 - y1_output_root_mean_squared_error: 0.7056 - y2_output_root_mean_squared_error: 1.3586 - val_loss: 13.6594 - val_y1_output_loss: 2.2729 - val_y2_output_loss: 11.1574 - val_y1_output_root_mean_squared_error: 1.5273 - val_y2_output_root_mean_squared_error: 3.3655
# Epoch 120/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4602 - y1_output_loss: 0.1413 - y2_output_loss: 0.3194 - y1_output_root_mean_squared_error: 0.3760 - y2_output_root_mean_squared_error: 0.5647 - val_loss: 1.2954 - val_y1_output_loss: 0.2213 - val_y2_output_loss: 1.0351 - val_y1_output_root_mean_squared_error: 0.4767 - val_y2_output_root_mean_squared_error: 1.0335
# Epoch 462/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4728 - y1_output_loss: 0.1300 - y2_output_loss: 0.3396 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.5848 - val_loss: 1.2727 - val_y1_output_loss: 0.2253 - val_y2_output_loss: 1.0066 - val_y1_output_root_mean_squared_error: 0.4808 - val_y2_output_root_mean_squared_error: 1.0205
# Epoch 463/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4525 - y1_output_loss: 0.1292 - y2_output_loss: 0.3197 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.5679 - val_loss: 1.0583 - val_y1_output_loss: 0.2038 - val_y2_output_loss: 0.8269 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.9221
# Epoch 464/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5358 - y1_output_loss: 0.1360 - y2_output_loss: 0.3953 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.6315 - val_loss: 1.3944 - val_y1_output_loss: 0.2076 - val_y2_output_loss: 1.1414 - val_y1_output_root_mean_squared_error: 0.4617 - val_y2_output_root_mean_squared_error: 1.0868
# Epoch 465/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.4489 - y1_output_loss: 0.1355 - y2_output_loss: 0.3114 - y1_output_root_mean_squared_error: 0.3685 - y2_output_root_mean_squared_error: 0.5595 - val_loss: 1.9346 - val_y1_output_loss: 0.3044 - val_y2_output_loss: 1.6092 - val_y1_output_root_mean_squared_error: 0.5568 - val_y2_output_root_mean_squared_error: 1.2746
# Epoch 466/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4556 - y1_output_loss: 0.1342 - y2_output_loss: 0.3186 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5661 - val_loss: 1.1339 - val_y1_output_loss: 0.2189 - val_y2_output_loss: 0.8907 - val_y1_output_root_mean_squared_error: 0.4694 - val_y2_output_root_mean_squared_error: 0.9558
# Epoch 467/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4845 - y1_output_loss: 0.1445 - y2_output_loss: 0.3380 - y1_output_root_mean_squared_error: 0.3814 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 1.7400 - val_y1_output_loss: 0.3921 - val_y2_output_loss: 1.3002 - val_y1_output_root_mean_squared_error: 0.6271 - val_y2_output_root_mean_squared_error: 1.1605
# Epoch 468/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4574 - y1_output_loss: 0.1375 - y2_output_loss: 0.3192 - y1_output_root_mean_squared_error: 0.3706 - y2_output_root_mean_squared_error: 0.5657 - val_loss: 1.5753 - val_y1_output_loss: 0.3335 - val_y2_output_loss: 1.1930 - val_y1_output_root_mean_squared_error: 0.5858 - val_y2_output_root_mean_squared_error: 1.1100
# Epoch 469/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4468 - y1_output_loss: 0.1371 - y2_output_loss: 0.3105 - y1_output_root_mean_squared_error: 0.3679 - y2_output_root_mean_squared_error: 0.5581 - val_loss: 1.3143 - val_y1_output_loss: 0.3257 - val_y2_output_loss: 0.9697 - val_y1_output_root_mean_squared_error: 0.5712 - val_y2_output_root_mean_squared_error: 0.9940
# Epoch 470/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4611 - y1_output_loss: 0.1343 - y2_output_loss: 0.3351 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5718 - val_loss: 2.1895 - val_y1_output_loss: 0.2807 - val_y2_output_loss: 1.8359 - val_y1_output_root_mean_squared_error: 0.5335 - val_y2_output_root_mean_squared_error: 1.3802
# Epoch 471/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5991 - y1_output_loss: 0.1685 - y2_output_loss: 0.4267 - y1_output_root_mean_squared_error: 0.4114 - y2_output_root_mean_squared_error: 0.6556 - val_loss: 1.1995 - val_y1_output_loss: 0.2157 - val_y2_output_loss: 0.9618 - val_y1_output_root_mean_squared_error: 0.4683 - val_y2_output_root_mean_squared_error: 0.9901
# Epoch 472/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.5639 - y1_output_loss: 0.1474 - y2_output_loss: 0.4162 - y1_output_root_mean_squared_error: 0.3824 - y2_output_root_mean_squared_error: 0.6463 - val_loss: 1.1185 - val_y1_output_loss: 0.2160 - val_y2_output_loss: 0.8852 - val_y1_output_root_mean_squared_error: 0.4670 - val_y2_output_root_mean_squared_error: 0.9489
# Epoch 473/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4332 - y1_output_loss: 0.1335 - y2_output_loss: 0.3005 - y1_output_root_mean_squared_error: 0.3670 - y2_output_root_mean_squared_error: 0.5464 - val_loss: 1.0358 - val_y1_output_loss: 0.1963 - val_y2_output_loss: 0.8227 - val_y1_output_root_mean_squared_error: 0.4485 - val_y2_output_root_mean_squared_error: 0.9136
# Epoch 474/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4200 - y1_output_loss: 0.1256 - y2_output_loss: 0.2932 - y1_output_root_mean_squared_error: 0.3539 - y2_output_root_mean_squared_error: 0.5429 - val_loss: 1.1406 - val_y1_output_loss: 0.1948 - val_y2_output_loss: 0.9225 - val_y1_output_root_mean_squared_error: 0.4463 - val_y2_output_root_mean_squared_error: 0.9703
# Epoch 475/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4937 - y1_output_loss: 0.1478 - y2_output_loss: 0.3432 - y1_output_root_mean_squared_error: 0.3848 - y2_output_root_mean_squared_error: 0.5879 - val_loss: 1.2335 - val_y1_output_loss: 0.2422 - val_y2_output_loss: 0.9579 - val_y1_output_root_mean_squared_error: 0.4980 - val_y2_output_root_mean_squared_error: 0.9927
# Epoch 476/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4897 - y1_output_loss: 0.1276 - y2_output_loss: 0.3607 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.6015 - val_loss: 1.4238 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 1.1201 - val_y1_output_root_mean_squared_error: 0.5232 - val_y2_output_root_mean_squared_error: 1.0724
# Epoch 477/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.4565 - y1_output_loss: 0.1348 - y2_output_loss: 0.3230 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.5664 - val_loss: 1.5164 - val_y1_output_loss: 0.2420 - val_y2_output_loss: 1.2518 - val_y1_output_root_mean_squared_error: 0.4976 - val_y2_output_root_mean_squared_error: 1.1264
# Epoch 478/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.7173 - y1_output_loss: 0.1740 - y2_output_loss: 0.5406 - y1_output_root_mean_squared_error: 0.4161 - y2_output_root_mean_squared_error: 0.7377 - val_loss: 1.6674 - val_y1_output_loss: 0.4856 - val_y2_output_loss: 1.1457 - val_y1_output_root_mean_squared_error: 0.7049 - val_y2_output_root_mean_squared_error: 1.0819
# Epoch 479/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4719 - y1_output_loss: 0.1393 - y2_output_loss: 0.3318 - y1_output_root_mean_squared_error: 0.3749 - y2_output_root_mean_squared_error: 0.5756 - val_loss: 1.3143 - val_y1_output_loss: 0.2227 - val_y2_output_loss: 1.0543 - val_y1_output_root_mean_squared_error: 0.4751 - val_y2_output_root_mean_squared_error: 1.0434
# Epoch 480/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5830 - y1_output_loss: 0.1517 - y2_output_loss: 0.4266 - y1_output_root_mean_squared_error: 0.3904 - y2_output_root_mean_squared_error: 0.6562 - val_loss: 1.5840 - val_y1_output_loss: 0.3870 - val_y2_output_loss: 1.1591 - val_y1_output_root_mean_squared_error: 0.6208 - val_y2_output_root_mean_squared_error: 1.0948
# Epoch 481/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5028 - y1_output_loss: 0.1481 - y2_output_loss: 0.3524 - y1_output_root_mean_squared_error: 0.3838 - y2_output_root_mean_squared_error: 0.5963 - val_loss: 1.1156 - val_y1_output_loss: 0.2220 - val_y2_output_loss: 0.8678 - val_y1_output_root_mean_squared_error: 0.4753 - val_y2_output_root_mean_squared_error: 0.9432
# Epoch 482/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4964 - y1_output_loss: 0.1337 - y2_output_loss: 0.3605 - y1_output_root_mean_squared_error: 0.3670 - y2_output_root_mean_squared_error: 0.6015 - val_loss: 0.9864 - val_y1_output_loss: 0.2230 - val_y2_output_loss: 0.7425 - val_y1_output_root_mean_squared_error: 0.4748 - val_y2_output_root_mean_squared_error: 0.8723
# Epoch 483/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4408 - y1_output_loss: 0.1362 - y2_output_loss: 0.3207 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5514 - val_loss: 3.4052 - val_y1_output_loss: 0.3450 - val_y2_output_loss: 2.9476 - val_y1_output_root_mean_squared_error: 0.5932 - val_y2_output_root_mean_squared_error: 1.7474
# Epoch 484/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4957 - y1_output_loss: 0.1286 - y2_output_loss: 0.3686 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.6063 - val_loss: 2.1481 - val_y1_output_loss: 0.4048 - val_y2_output_loss: 1.6747 - val_y1_output_root_mean_squared_error: 0.6406 - val_y2_output_root_mean_squared_error: 1.3182
# Epoch 485/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4763 - y1_output_loss: 0.1380 - y2_output_loss: 0.3384 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.5816 - val_loss: 1.6462 - val_y1_output_loss: 0.3120 - val_y2_output_loss: 1.2921 - val_y1_output_root_mean_squared_error: 0.5629 - val_y2_output_root_mean_squared_error: 1.1530
# Epoch 486/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5454 - y1_output_loss: 0.1458 - y2_output_loss: 0.4016 - y1_output_root_mean_squared_error: 0.3789 - y2_output_root_mean_squared_error: 0.6339 - val_loss: 1.1373 - val_y1_output_loss: 0.2378 - val_y2_output_loss: 0.8901 - val_y1_output_root_mean_squared_error: 0.4896 - val_y2_output_root_mean_squared_error: 0.9474
# Epoch 487/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4935 - y1_output_loss: 0.1392 - y2_output_loss: 0.3525 - y1_output_root_mean_squared_error: 0.3730 - y2_output_root_mean_squared_error: 0.5953 - val_loss: 1.1837 - val_y1_output_loss: 0.2547 - val_y2_output_loss: 0.8995 - val_y1_output_root_mean_squared_error: 0.5092 - val_y2_output_root_mean_squared_error: 0.9615
# Epoch 488/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3948 - y1_output_loss: 0.1261 - y2_output_loss: 0.2768 - y1_output_root_mean_squared_error: 0.3512 - y2_output_root_mean_squared_error: 0.5211 - val_loss: 2.4880 - val_y1_output_loss: 0.5399 - val_y2_output_loss: 1.8779 - val_y1_output_root_mean_squared_error: 0.7365 - val_y2_output_root_mean_squared_error: 1.3948
# Epoch 489/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.5855 - y1_output_loss: 0.1690 - y2_output_loss: 0.4136 - y1_output_root_mean_squared_error: 0.4116 - y2_output_root_mean_squared_error: 0.6450 - val_loss: 1.0455 - val_y1_output_loss: 0.2287 - val_y2_output_loss: 0.7884 - val_y1_output_root_mean_squared_error: 0.4810 - val_y2_output_root_mean_squared_error: 0.9023
# Epoch 490/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.5086 - y1_output_loss: 0.1344 - y2_output_loss: 0.3772 - y1_output_root_mean_squared_error: 0.3631 - y2_output_root_mean_squared_error: 0.6138 - val_loss: 1.6916 - val_y1_output_loss: 0.4888 - val_y2_output_loss: 1.1782 - val_y1_output_root_mean_squared_error: 0.7058 - val_y2_output_root_mean_squared_error: 1.0924
# Epoch 491/500
# 614/614 [==============================] - 0s 178us/sample - loss: 0.5781 - y1_output_loss: 0.1679 - y2_output_loss: 0.4083 - y1_output_root_mean_squared_error: 0.4114 - y2_output_root_mean_squared_error: 0.6394 - val_loss: 1.2225 - val_y1_output_loss: 0.2403 - val_y2_output_loss: 0.9594 - val_y1_output_root_mean_squared_error: 0.4932 - val_y2_output_root_mean_squared_error: 0.9895
# Epoch 492/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3969 - y1_output_loss: 0.1124 - y2_output_loss: 0.2832 - y1_output_root_mean_squared_error: 0.3364 - y2_output_root_mean_squared_error: 0.5326 - val_loss: 1.3436 - val_y1_output_loss: 0.2466 - val_y2_output_loss: 1.0715 - val_y1_output_root_mean_squared_error: 0.5040 - val_y2_output_root_mean_squared_error: 1.0438
# Epoch 493/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.6542 - y1_output_loss: 0.1519 - y2_output_loss: 0.4974 - y1_output_root_mean_squared_error: 0.3900 - y2_output_root_mean_squared_error: 0.7086 - val_loss: 1.1100 - val_y1_output_loss: 0.2375 - val_y2_output_loss: 0.8552 - val_y1_output_root_mean_squared_error: 0.4906 - val_y2_output_root_mean_squared_error: 0.9324
# Epoch 494/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4941 - y1_output_loss: 0.1355 - y2_output_loss: 0.3551 - y1_output_root_mean_squared_error: 0.3696 - y2_output_root_mean_squared_error: 0.5979 - val_loss: 1.0732 - val_y1_output_loss: 0.1746 - val_y2_output_loss: 0.8771 - val_y1_output_root_mean_squared_error: 0.4212 - val_y2_output_root_mean_squared_error: 0.9465
# Epoch 495/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4239 - y1_output_loss: 0.1256 - y2_output_loss: 0.2991 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.5461 - val_loss: 1.2514 - val_y1_output_loss: 0.2824 - val_y2_output_loss: 0.9611 - val_y1_output_root_mean_squared_error: 0.5356 - val_y2_output_root_mean_squared_error: 0.9821
# Epoch 496/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4482 - y1_output_loss: 0.1356 - y2_output_loss: 0.3136 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.5591 - val_loss: 1.3243 - val_y1_output_loss: 0.2892 - val_y2_output_loss: 1.0153 - val_y1_output_root_mean_squared_error: 0.5424 - val_y2_output_root_mean_squared_error: 1.0150
# Epoch 497/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5364 - y1_output_loss: 0.1566 - y2_output_loss: 0.3837 - y1_output_root_mean_squared_error: 0.3904 - y2_output_root_mean_squared_error: 0.6196 - val_loss: 1.5601 - val_y1_output_loss: 0.2981 - val_y2_output_loss: 1.2147 - val_y1_output_root_mean_squared_error: 0.5534 - val_y2_output_root_mean_squared_error: 1.1197
# Epoch 498/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.7432 - y1_output_loss: 0.2119 - y2_output_loss: 0.5313 - y1_output_root_mean_squared_error: 0.4600 - y2_output_root_mean_squared_error: 0.7291 - val_loss: 1.8934 - val_y1_output_loss: 0.3801 - val_y2_output_loss: 1.5179 - val_y1_output_root_mean_squared_error: 0.6202 - val_y2_output_root_mean_squared_error: 1.2283
# Epoch 499/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5619 - y1_output_loss: 0.1440 - y2_output_loss: 0.4138 - y1_output_root_mean_squared_error: 0.3804 - y2_output_root_mean_squared_error: 0.6459 - val_loss: 1.1662 - val_y1_output_loss: 0.2319 - val_y2_output_loss: 0.9210 - val_y1_output_root_mean_squared_error: 0.4880 - val_y2_output_root_mean_squared_error: 0.9633
# Epoch 500/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.5863 - y1_output_loss: 0.1645 - y2_output_loss: 0.4182 - y1_output_root_mean_squared_error: 0.4057 - y2_output_root_mean_squared_error: 0.6494 - val_loss: 1.1194 - val_y1_output_loss: 0.2469 - val_y2_output_loss: 0.8419 - val_y1_output_root_mean_squared_error: 0.4999 - val_y2_output_root_mean_squared_error: 0.9325

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 1.1194 - y1_output_loss: 0.2526 - y2_output_loss: 0.9191 - y1_output_root_mean_squared_error: 0.4999 - y2_output_root_mean_squared_error: 0.9325
# Loss = 1.1194250428831423, Y1_loss = 0.2525944411754608, Y1_mse = 0.49990957975387573, Y2_loss = 0.9191089868545532, Y2_mse = 0.932478129863739

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
