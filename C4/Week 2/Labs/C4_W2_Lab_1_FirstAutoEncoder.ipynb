# %% [markdown]
# # Ungraded Lab: First Autoencoder
#
# In this lab, you will build your first simple autoencoder. This will take in three-dimensional data, encodes it to two dimensions, and decodes it back to 3D.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Prepare and preview the dataset
#
# You will first create a synthetic dataset to act as input to the autoencoder. You can do that with the function below.

# %%
def generate_data(m):
    '''plots m random points on a 3D plane'''

    angles = np.random.rand(m) * 3 * np.pi / 2 - 0.5
    data = np.empty((m, 3))
    data[:,0] = np.cos(angles) + np.sin(angles)/2 + 0.1 * np.random.randn(m)/2
    data[:,1] = np.sin(angles) * 0.7 + 0.1 * np.random.randn(m) / 2
    data[:,2] = data[:, 0] * 0.1 + data[:, 1] * 0.3 + 0.1 * np.random.randn(m)

    return data

# %%
# use the function above to generate data points
X_train = generate_data(100)
X_train = X_train - X_train.mean(axis=0, keepdims=0)

# preview the data
ax = plt.axes(projection='3d')
ax.scatter3D(X_train[:, 0], X_train[:, 1], X_train[:, 2], cmap='Reds');
# Out:
# <ipython-input-3-42bc7d7259f7>:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter3D(X_train[:, 0], X_train[:, 1], X_train[:, 2], cmap='Reds');

# %% [markdown]
# ## Build the Model
#
# Now you will build the simple encoder-decoder model. Notice the number of neurons in each Dense layer. The model will contract in the encoder then expand in the decoder.

# %%
encoder = keras.models.Sequential([keras.layers.Dense(2, input_shape=[3])])
decoder = keras.models.Sequential([keras.layers.Dense(3, input_shape=[2])])

autoencoder = keras.models.Sequential([encoder, decoder])

# %% [markdown]
# ## Compile the Model
#
# You can then setup the model for training.

# %%
autoencoder.compile(loss='mse', optimizer=keras.optimizers.SGD(lr=0.1))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %% [markdown]
# ## Train the Model
#
# You will configure the training to also use the input data as your target output. In our example, that will be `X_train`.

# %%
history = autoencoder.fit(X_train, X_train, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 20ms/step - loss: 0.4507
# Epoch 2/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4346
# Epoch 3/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4215
# Epoch 4/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4095
# Epoch 5/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3979
# Epoch 6/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3887
# Epoch 7/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3787
# Epoch 8/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3701
# Epoch 9/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3623
# Epoch 10/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3537
# Epoch 11/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3477
# Epoch 12/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3412
# Epoch 13/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3355
# Epoch 14/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3305
# Epoch 15/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3239
# Epoch 16/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3185
# Epoch 17/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3131
# Epoch 18/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3079
# Epoch 19/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3029
# Epoch 20/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2976
# Epoch 21/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2931
# Epoch 22/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2885
# Epoch 23/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2845
# Epoch 24/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2798
# Epoch 25/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2762
# Epoch 26/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2726
# Epoch 27/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2690
# Epoch 28/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2654
# Epoch 29/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2624
# Epoch 30/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2590
# Epoch 31/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2558
# Epoch 32/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2526
# Epoch 33/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2496
# Epoch 34/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2468
# Epoch 35/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2440
# Epoch 36/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2414
# Epoch 37/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2386
# Epoch 38/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2353
# Epoch 39/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2322
# Epoch 40/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2294
# Epoch 41/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2264
# Epoch 42/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2236
# Epoch 43/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2205
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2177
# Epoch 45/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2149
# Epoch 46/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2123
# Epoch 47/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2098
# Epoch 48/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2069
# Epoch 49/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2041
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2015
# Epoch 51/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1986
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1958
# Epoch 53/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1937
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1912
# Epoch 55/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1890
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1867
# Epoch 57/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1842
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1819
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1793
# Epoch 60/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1766
# Epoch 61/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1741
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1718
# Epoch 63/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1694
# Epoch 64/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1670
# Epoch 65/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1648
# Epoch 66/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1626
# Epoch 67/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1604
# Epoch 68/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1581
# Epoch 69/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1561
# Epoch 70/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1541
# Epoch 71/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1520
# Epoch 72/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1499
# Epoch 73/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1480
# Epoch 74/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1459
# Epoch 75/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1442
# Epoch 76/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1424
# Epoch 77/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1405
# Epoch 78/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1385
# Epoch 79/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1370
# Epoch 80/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1352
# Epoch 81/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1334
# Epoch 82/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1317
# Epoch 83/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1302
# Epoch 84/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1288
# Epoch 85/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1270
# Epoch 86/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1253
# Epoch 87/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1240
# Epoch 88/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1225
# Epoch 89/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1209
# Epoch 90/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1194
# Epoch 91/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1180
# Epoch 92/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1167
# Epoch 93/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1153
# Epoch 94/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1140
# Epoch 95/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1128
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1116
# Epoch 97/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1104
# Epoch 98/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1094
# Epoch 99/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1084
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1074
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 102/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1054
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1044
# Epoch 104/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1035
# Epoch 105/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1024
# Epoch 106/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1015
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1006
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0996
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0988
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0980
# Epoch 111/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0969
# Epoch 112/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0963
# Epoch 113/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0954
# Epoch 114/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0946
# Epoch 115/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0939
# Epoch 116/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0930
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0924
# Epoch 118/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0918
# Epoch 119/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0909
# Epoch 120/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0903
# Epoch 121/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0897
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0891
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0886
# Epoch 124/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0880
# Epoch 125/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0874
# Epoch 126/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0869
# Epoch 127/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0864
# Epoch 128/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0859
# Epoch 129/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0854
# Epoch 130/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0851
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0846
# Epoch 132/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0841
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0837
# Epoch 134/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0832
# Epoch 135/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0828
# Epoch 136/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0826
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0822
# Epoch 138/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0818
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0815
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0810
# Epoch 141/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0807
# Epoch 142/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0803
# Epoch 143/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0799
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0796
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0793
# Epoch 146/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0790
# Epoch 147/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0787
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0784
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0782
# Epoch 150/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0779
# Epoch 151/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0776
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0773
# Epoch 153/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0771
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0769
# Epoch 155/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0766
# Epoch 156/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0765
# Epoch 157/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0763
# Epoch 158/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0760
# Epoch 159/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0757
# Epoch 160/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0755
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0753
# Epoch 162/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0750
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0749
# Epoch 164/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0746
# Epoch 165/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0744
# Epoch 166/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0742
# Epoch 167/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0741
# Epoch 168/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0739
# Epoch 169/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0737
# Epoch 170/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0735
# Epoch 171/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0733
# Epoch 172/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0731
# Epoch 173/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0729
# Epoch 174/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0727
# Epoch 175/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0725
# Epoch 176/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0723
# Epoch 177/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0722
# Epoch 178/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0720
# Epoch 179/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0719
# Epoch 180/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0717
# Epoch 181/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0715
# Epoch 182/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0714
# Epoch 183/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0713
# Epoch 184/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0711
# Epoch 185/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0709
# Epoch 186/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0707
# Epoch 187/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0706
# Epoch 188/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0705
# Epoch 189/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0703
# Epoch 190/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0702
# Epoch 191/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0700
# Epoch 192/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0699
# Epoch 193/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0698
# Epoch 194/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0696
# Epoch 195/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0695
# Epoch 196/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0694
# Epoch 197/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0692
# Epoch 198/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0691
# Epoch 199/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0689
# Epoch 200/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0688

# %% [markdown]
# ## Plot the encoder output
#
# As mentioned, you can use the encoder to compress the input to two dimensions.

# %%
# encode the data
codings = encoder.predict(X_train)

# see a sample input encoder output pair
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
# Out:
# 4/4 [==============================] - 0s 5ms/step
# input point: [1.08487066 0.33653658 0.34900392]
# encoded point: [ 1.032128   -0.00827748]

# %%
# plot all encoder outputs
fig = plt.figure(figsize=(4,3))
plt.plot(codings[:,0], codings[:, 1], "b.")
plt.xlabel("$z_1$", fontsize=18)
plt.ylabel("$z_2$", fontsize=18, rotation=0)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the Decoder output
#
# The decoder then tries to reconstruct the original input. See the outputs below. You will see that although not perfect, it still follows the general shape of the original input.

# %%
# decode the encoder output
decodings = decoder.predict(codings)

# see a sample output for a single point
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
print(f'decoded point: {decodings[0]}')
# Out:
# 4/4 [==============================] - 0s 4ms/step
# input point: [1.08487066 0.33653658 0.34900392]
# encoded point: [ 1.032128   -0.00827748]
# decoded point: [0.9979694  0.45685238 0.11864953]

# %%
# plot the decoder output
ax = plt.axes(projection='3d')
ax.scatter3D(decodings[:, 0], decodings[:, 1], decodings[:, 2], c=decodings[:, 0], cmap='Reds');
